# %%
mi_diccionario = {"Hola":"Hello", "Adios": "Bye"}
print(mi_diccionario["Hola"])
mi_diccionario["Rojo"]="Red"
print(mi_diccionario)
mi_diccionario["Rojo"]="Orange"
print(mi_diccionario)
campistas = {"Victor":{"edad":30, "celular" : 3168433904, "direccion": "Calle 70NOrte"},
             "maria":{"edad": 25, "celular": 3216548912, "direccion": "Calle 70Sur"}}
print(campistas)
paises =("España", "Italia", "Alemania")
capitales ={paises[0]:"Madrid", paises[1]: "Roma", paises[2]: "Berlin"}
print(capitales)
del capitales [paises[0]]
print(capitales)
print(campistas.get("ana"," Este campista no existe"))
print(campistas.keys())
print(campistas.values())
print(len(campistas))
campistas.clear()
print(campistas)
# Out:
# Hello
# {'Hola': 'Hello', 'Adios': 'Bye', 'Rojo': 'Red'}
# {'Hola': 'Hello', 'Adios': 'Bye', 'Rojo': 'Orange'}
# {'Victor': {'edad': 30, 'celular': 3168433904, 'direccion': 'Calle 70NOrte'}, 'maria': {'edad': 25, 'celular': 3216548912, 'direccion': 'Calle 70Sur'}}
# {'España': 'Madrid', 'Italia': 'Roma', 'Alemania': 'Berlin'}
# {'Italia': 'Roma', 'Alemania': 'Berlin'}
#  Este campista no existe
# dict_keys(['Victor', 'maria'])
# dict_values([{'edad': 30, 'celular': 3168433904, 'direccion': 'Calle 70NOrte'}, {'edad': 25, 'celular': 3216548912, 'direccion': 'Calle 70Sur'}])
# 2
# {}
