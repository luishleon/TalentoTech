# %%
vocales = ["a","a","e","i","o","u"] # lista
print(vocales)
vocales
# Out:
# ['a', 'a', 'e', 'i', 'o', 'u']
# ['a', 'a', 'e', 'i', 'o', 'u']

# %%
vocales = ("a","a","e","i","o","u") # tupla
print(vocales)
vocales
# Out:
# ('a', 'a', 'e', 'i', 'o', 'u')
# ('a', 'a', 'e', 'i', 'o', 'u')

# %%
vocales = {"a","a","e","i","o","u"} # conjunto (elementos únicos)
print(vocales)
vocales
# Out:
# {'u', 'e', 'i', 'o', 'a'}
# {'a', 'e', 'i', 'o', 'u'}

# %%
#diccionario:
d = {"acero":"material","elefante":"animal","iglesia":"recinto","oscar":"premio","utopía":"difícil de alcanzar"}
d
# Out:
# {'acero': 'material',
#  'elefante': 'animal',
#  'iglesia': 'recinto',
#  'oscar': 'premio',
#  'utopía': 'difícil de alcanzar'}

# %%
print(d)
# Out:
# {'acero': 'material', 'elefante': 'animal', 'iglesia': 'recinto', 'oscar': 'premio', 'utopía': 'difícil de alcanzar'}

# %%
d = {

   "acero"    :  "material"                ,
   "elefante" :  "animal"                  ,
   "iglesia"  :  "recinto"                 ,
   "oscar"    :  "premio"                  ,
   "utopía"   :  "difícil de alcanzar"
}
d
# Out:
# {'acero': 'material',
#  'elefante': 'animal',
#  'iglesia': 'recinto',
#  'oscar': 'premio',
#  'utopía': 'difícil de alcanzar'}

# %%
print(d)
# Out:
# {'acero': 'material', 'elefante': 'animal', 'iglesia': 'recinto', 'oscar': 'premio', 'utopía': 'difícil de alcanzar'}

# %%
d
# Out:
# {'acero': 'material',
#  'elefante': 'animal',
#  'iglesia': 'recinto',
#  'oscar': 'premio',
#  'utopía': 'difícil de alcanzar'}
