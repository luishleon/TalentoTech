# %%
import pandas as pd

# Load the CSV file into a pandas DataFrame
df = pd.read_csv('/content/IceCreamData.csv')

# Display the first few rows to confirm loading
display(df.head())
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
# Define the output Excel file name
output_excel_file = 'IceCreamData.xlsx'

# Save the DataFrame to an Excel file
df.to_excel(output_excel_file, index=False)

print(f"DataFrame successfully saved to {output_excel_file}")
# Out:
# DataFrame successfully saved to IceCreamData.xlsx

# %% [markdown]
# ### Download your Excel file here:
#
# [Download IceCreamData.xlsx](IceCreamData.xlsx)
